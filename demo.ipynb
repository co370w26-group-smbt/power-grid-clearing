# %%
import gurobipy as gp
from gurobipy import GRB
from pathlib import Path

# %%
DA_CLEARANCE_LP_FILE = Path('da-clearance-lp') / 'results' / '118-bus' / 'model-118bus.lp'
FTR_CLEARANCE_LP_FILE = Path('ftr_clearance') / 'results' / '118-bus' / 'ftr_clearance.lp'

# %%
da_clearance_lp = gp.read(DA_CLEARANCE_LP_FILE.as_posix())
ftr_clearance_lp = gp.read(FTR_CLEARANCE_LP_FILE.as_posix())
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2762801
# Set parameter LicenseID to value 2762801
# Academic license - for non-commercial use only - expires 2027-01-10
# Read LP format model from file da-clearance-lp/results/118-bus/model-118bus.lp
# Reading time = 15.62 seconds
# : 65215 rows, 1078 columns, 59378864 nonzeros
# Read LP format model from file ftr_clearance/results/118-bus/ftr_clearance.lp
# Reading time = 0.15 seconds
# : 2888 rows, 250 columns, 675152 nonzeros

# %%
da_clearance_lp.optimize()
# Out:
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (mac64[arm] - Darwin 25.4.0 25E253)
#
# CPU model: Apple M1 Max
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 65215 rows, 1078 columns and 59378864 nonzeros (Max)
#
# CPU model: Apple M1 Max
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 65215 rows, 1078 columns and 59378864 nonzeros (Max)
# Model fingerprint: 0x24721855
# Model has 1076 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e-04, 1e+00]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+03]
#
# Presolve removed 36483 rows and 294 columns (presolve time = 6s)...
# Presolve removed 46004 rows and 294 columns
# Presolve time: 14.89s
# Presolved: 1078 rows, 29782 columns, 30502604 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# ...

# %%
ftr_clearance_lp.optimize()
# Out:
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (mac64[arm] - Darwin 25.4.0 25E253)
#
# CPU model: Apple M1 Max
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2888 rows, 250 columns and 675152 nonzeros (Max)
# Model fingerprint: 0xf78b9aca
# Model has 250 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e-04, 1e+00]
#   Objective range  [8e+00, 3e+01]
#   Bounds range     [3e+01, 2e+02]
#   RHS range        [2e+02, 5e+02]
#
#
# CPU model: Apple M1 Max
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2888 rows, 250 columns and 675152 nonzeros (Max)
# Model fingerprint: 0xf78b9aca
# Model has 250 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e-04, 1e+00]
#   Objective range  [8e+00, 3e+01]
#   Bounds range     [3e+01, 2e+02]
#   RHS range        [2e+02, 5e+02]
#
# Presolve removed 1790 rows and 8 columns
# ...

# %% [markdown]
# # For variable interpretations, see individual notebooks
